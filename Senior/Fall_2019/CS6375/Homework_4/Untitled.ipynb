# %%
import numpy as np
import random

# %%
l = np.array(list(range(0,1000)))
l[np.floor(np.random.uniform(0,1000,1000)).astype(int)]
# Out:
# array([600, 955, 968, 450, 237, 505,  40,  57, 338, 661, 836, 498,  90,
#        214, 957, 478, 186, 679, 740, 164, 553, 557, 939, 348, 155, 591,
#        652, 713, 490, 496,   3, 624, 922, 718, 669, 157, 923, 105, 658,
#        822, 761, 507, 774, 948, 440, 611, 312, 747, 264,  10, 318, 323,
#        369, 304,  99,  25, 870, 710, 690, 353, 688, 293, 164, 248, 986,
#        975, 278, 771, 535, 998, 923, 611, 605, 618, 266, 817,  62, 379,
#        556, 656, 138, 507, 970, 905, 303, 730,  72, 417, 245, 162, 711,
#        661, 629, 727, 643, 864, 230, 537, 834, 899, 765, 955, 844, 555,
#        800, 135, 704, 593, 489, 105, 428,  26, 914, 798, 848, 474, 291,
#        563,  53, 864, 789, 940, 652, 968, 160,   0, 516, 706, 285, 199,
#        413, 589, 292, 759, 309, 547, 586, 506, 924, 945, 975, 183, 423,
#        608, 198, 309,  46, 994,  64, 471, 933, 707,   8, 274, 979, 782,
#        538, 133, 493, 836, 201, 503, 558, 920, 913,  40, 747, 100, 830,
# ...

# %%
n = np.array([[i + j for i in range(10)] for j in range(10)])
l = list(range(0,10 * 10))
np.random.shuffle(l)
new = np.ndarray.flatten(n)
new[l[0:50]] = 0
np.reshape(new,(10,10))
# Out:
# array([[ 0,  0,  2,  3,  0,  0,  6,  7,  0,  9],
#        [ 0,  0,  3,  0,  5,  6,  7,  0,  0,  0],
#        [ 0,  0,  4,  5,  6,  7,  0,  9, 10,  0],
#        [ 0,  0,  0,  0,  7,  8,  9, 10,  0,  0],
#        [ 0,  5,  0,  7,  8,  0, 10, 11, 12,  0],
#        [ 5,  6,  0,  8,  0,  0, 11, 12, 13, 14],
#        [ 6,  0,  8,  9, 10, 11,  0, 13, 14,  0],
#        [ 0,  0,  9,  0,  0, 12,  0,  0,  0, 16],
#        [ 0,  0, 10,  0, 12,  0, 14,  0, 16,  0],
#        [ 9,  0,  0, 12,  0,  0,  0, 16,  0, 18]])

# %%
K = [1,2,3]
R = [5,10,20]
combs = [(k,r) for k in K for r in R]
for k, r in combs:
    print k
# Out:
# 1
# 1
# 1
# 2
# 2
# 2
# 3
# 3
# 3

# %%
# Out:
# ''
