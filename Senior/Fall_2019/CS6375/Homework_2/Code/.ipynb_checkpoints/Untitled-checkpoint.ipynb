# %%
import pandas as pd
import numpy  as np
import os
import re
from collections import Counter

# %%
directory = "/home/daniel/Documents/homework/Senior/Fall_2019/CS6375/Homework_2/Code/"

# %%
def getAllWordsFromString(words):
    return re.sub('[^a-zA-Z]+', ' ', allTrainWords).lower().split(" ")

def getCountOfWords(words, allUniqueWords):
    dictionary = {}
    for word in allUniqueWords:
        dictionary = mergeTwoDicts(dictionary, {word: words.count(word)})
    return dictionary
        
def mergeTwoDicts(x, y):
    z = x.copy()
    z.update(y)
    return z

# %%
def getDirectoryContents(dataDirectory):
    contents = np.array([])
    for fileName in os.listdir(dataDirectory):
        contents = np.append(contents, [open(dataDirectory + fileName).read()])
    return contents


        

def getBagOfWordsDataFrame(data, classifier, allUniqueWords):
    df = pd.DataFrame(columns=allUniqueWords)
    for i in data:
        i   = i.lower()
        row = pd.DataFrame(columns=allUniqueWords)
        
        for

# %%
trainData = getDirectoryContents(directory + "train/ham/")
testData  = getDirectoryContents(directory + "test/ham/")

# %%
#Transform all files into a single string.
allTrainWords = ''.join(trainData)
#Retrieve all unique WORDS - Remove all words with numbers/punctuation and replace with space.
allUniqueWords = np.unique(getAllWordsFromString(allTrainWords))

# %%
#train bag of words
trainBOW = pd.Dataframe
#train bernoulli
trainBer

# %%
getCountOfWords(trainData[0], allUniqueWords)
# Out:
# {'osire': 0,
#  'bossier': 0,
#  'four': 0,
#  'andre': 0,
#  'frayre': 0,
#  'woody': 0,
#  'whose': 0,
#  'winfree': 0,
#  'buddy': 0,
#  'aug': 0,
#  'james': 0,
#  'hgpl': 0,
#  'speckels': 0,
#  'hunaid': 0,
#  'lord': 0,
#  'sorry': 0,
#  'ppep': 0,
#  'lora': 0,
#  'updated': 0,
#  'downstream': 0,
#  'hitchcock': 0,
#  'updates': 0,
#  'affect': 0,
#  'cashout': 0,
#  'companies': 0,
#  'solution': 0,
#  'succession': 0,
#  'unauthorised': 0,
#  'hesse': 0,
#  'jeff': 0,
#  'charter': 0,
#  'force': 0,
#  'farmersubject': 0,
#  'miller': 0,
#  'budget': 0,
#  'likely': 0,
#  'porfolio': 0,
#  'even': 0,
#  'edmondson': 0,
#  'errors': 0,
#  'theriot': 0,
#  'hate': 0,
#  'briley': 0,
#  'fingers': 0,
#  'designing': 0,
#  'new': 0,
#  'net': 0,
#  'guadcomm': 0,
#  'ever': 0,
#  'specialist': 0,
#  'mechanisms': 0,
#  'never': 0,
#  'gladewater': 0,
#  'reported': 0,
#  'active': 0,
#  'dry': 0,
#  'k': 11,
#  'economics': 0,
#  'reports': 0,
#  'credit': 0,
#  'cindy': 0,
#  'buckley': 0,
#  'karie': 0,
#  'gottlob': 0,
#  'joshua': 0,
#  'appropriately': 0,
#  'fantastic': 0,
#  'corpaorate': 0,
#  'explained': 0,
#  'replace': 0,
#  'brought': 0,
#  'counts': 0,
#  'univ': 0,
#  'unit': 0,
#  'spoke': 0,
#  'keith': 0,
#  'junel': 0,
#  'call': 0,
#  'therefore': 0,
#  'recommend': 0,
#  'type': 0,
#  'tell': 0,
#  'guggisberg': 0,
#  'meers': 0,
#  'successful': 0,
#  'nowlan': 0,
#  'billyoung': 0,
#  'ward': 0,
#  'aligned': 0,
#  'circumstances': 0,
#  'locked': 0,
#  'room': 0,
#  'rights': 0,
#  'pursue': 0,
#  'setup': 0,
#  'luongsubject': 0,
#  'concepts': 0,
#  'exceptions': 0,
#  'roos': 0,
#  'giron': 0,
#  'example': 0,
#  'grimes': 0,
#  'give': 0,
#  'agmt': 0,
#  'caution': 0,
#  'reviewing': 0,
#  'want': 0,
#  'hoc': 0,
#  'complaining': 0,
#  'hol': 0,
#  'damage': 0,
#  'machine': 0,
#  'how': 0,
#  'methodology': 0,
#  'hou': 2,
#  'answer': 0,
#  'ronnie': 0,
#  'mueller': 0,
#  'typed': 0,
#  'reconciled': 0,
#  'invitation': 0,
#  'loyalty': 0,
#  'wrong': 0,
#  'president': 0,
#  'goodbys': 0,
#  'purchase': 0,
#  'vance': 0,
#  'attempt': 0,
#  'ionaalphonso': 0,
#  'effective': 0,
#  'macphail': 0,
#  'presiding': 0,
#  'hankssubject': 0,
#  'hetherington': 0,
#  'goodbye': 0,
#  'keeps': 0,
#  'operate': 0,
#  'operations': 0,
#  'feedback': 0,
#  'vary': 0,
#  'murray': 0,
#  'fellas': 0,
#  'before': 0,
#  'shawnee': 0,
#  'rescheduled': 0,
#  'personal': 0,
#  'rankings': 0,
#  'fix': 0,
#  'revenue': 0,
#  'better': 0,
#  'differently': 0,
#  'weeks': 0,
#  'fil': 0,
#  'shively': 0,
#  'combination': 0,
#  'lambert': 0,
#  'lannou': 0,
#  'withdrawal': 0,
#  'schools': 0,
#  'shah': 0,
#  'represents': 0,
#  'skills': 0,
#  'cornhusker': 0,
#  'went': 0,
#  'briana': 0,
#  'side': 0,
#  'luck': 0,
#  'afforded': 0,
#  'financial': 0,
#  'principles': 0,
#  'skins': 0,
#  'riegel': 0,
#  'trading': 0,
#  'fercsr': 0,
#  'aids': 0,
#  'dawn': 0,
#  'rw': 0,
#  'rs': 1,
#  'crucial': 0,
#  'george': 0,
#  'content': 0,
#  're': 8,
#  'encourage': 0,
#  'ra': 7,
#  'smi': 0,
#  'rc': 0,
#  'donahue': 0,
#  'rh': 0,
#  'foundation': 0,
#  'turning': 0,
#  'assured': 0,
#  'resume': 0,
#  'friends': 0,
#  'bldg': 0,
#  'villareal': 0,
#  'checked': 0,
#  'estimate': 0,
#  'desks': 0,
#  'knit': 0,
#  'shipper': 0,
#  'starts': 0,
#  'messages': 0,
#  'moment': 0,
#  'heading': 0,
#  'leila': 0,
#  'choices': 0,
#  'isn': 0,
#  'lamphier': 0,
#  'stewart': 0,
#  'eileen': 0,
#  'features': 0,
#  'hoop': 0,
#  'hook': 0,
#  'downside': 0,
#  'chevron': 0,
#  'wasn': 0,
#  'leaders': 0,
#  'service': 0,
#  'indicate': 0,
#  'xii': 0,
#  'sekse': 0,
#  'recruiting': 0,
#  'needed': 0,
#  'master': 0,
#  'listed': 0,
#  'gilbert': 0,
#  'recent': 0,
#  'genesis': 0,
#  'rewards': 0,
#  'unallocatable': 0,
#  'somewhat': 0,
#  'helen': 0,
#  'white': 0,
#  'cilco': 0,
#  'showed': 0,
#  'princeton': 0,
#  'database': 0,
#  'second': 0,
#  'burchfield': 0,
#  'matter': 0,
#  'speaking': 0,
#  'skilling': 0,
#  'willingness': 0,
#  'runner': 0,
#  'htmsubject': 0,
#  'caleb': 0,
#  'mine': 0,
#  'increment': 0,
#  'seen': 0,
#  'seem': 0,
#  'churn': 0,
#  'seek': 0,
#  'dozen': 0,
#  'kaye': 0,
#  'responsible': 0,
#  'moscoso': 0,
#  'causing': 0,
#  'eiben': 0,
#  'season': 0,
#  'tunnels': 0,
#  'shall': 0,
#  'mystique': 0,
#  'kean': 0,
#  'wells': 0,
#  'mario': 0,
#  'regular': 0,
#  'cummings': 0,
#  'letter': 0,
#  'entry': 0,
#  'retaining': 0,
#  'marie': 0,
#  'maria': 0,
#  'mtbe': 0,
#  'don': 1,
#  'grove': 0,
#  'doc': 0,
#  'camp': 0,
#  'm': 14,
#  'doe': 0,
#  'points': 0,
#  'tech': 0,
#  'mailing': 0,
#  'dow': 0,
#  'came': 0,
#  'kristen': 0,
#  'incorporate': 0,
#  'nee': 0,
#  'meetings': 0,
#  'teresa': 0,
#  'nominated': 0,
#  'attempts': 0,
#  'liberty': 0,
#  'nominates': 0,
#  'deedee': 0,
#  'lessons': 0,
#  'busy': 0,
#  'clicked': 0,
#  'louise': 0,
#  'menu': 0,
#  'bellflower': 0,
#  'appreciated': 0,
#  'bush': 0,
#  'venturatos': 0,
#  'cousino': 0,
#  'rich': 0,
#  'folks': 0,
#  'folder': 0,
#  'rice': 1,
#  'lady': 0,
#  'conatser': 0,
#  'evey': 0,
#  'stop': 0,
#  'coast': 0,
#  'urbanek': 0,
#  'redelivered': 0,
#  'sandy': 0,
#  'earl': 0,
#  'krishnaswamy': 0,
#  'bar': 0,
#  'lettersubject': 0,
#  'nicely': 0,
#  'fields': 0,
#  'greene': 0,
#  'cokinos': 0,
#  'bad': 0,
#  'release': 0,
#  'respond': 0,
#  'reference': 0,
#  'testing': 0,
#  'zones': 0,
#  'decided': 0,
#  'radius': 0,
#  'result': 0,
#  'clem': 0,
#  'hydrocarbon': 0,
#  'subject': 2,
#  'pete': 0,
#  'said': 0,
#  'inappropriate': 0,
#  'butch': 0,
#  'falbaum': 0,
#  'protected': 0,
#  'melissa': 0,
#  'clynes': 0,
#  'timeframe': 0,
#  'shults': 0,
#  'extend': 0,
#  'rolled': 0,
#  'herrera': 0,
#  'authorizing': 0,
#  'vernon': 0,
#  'here': 0,
#  'extent': 0,
#  'nonregulated': 0,
#  'suggested': 0,
#  'prudential': 0,
#  'brown': 0,
#  'met': 5,
#  'country': 0,
#  'against': 0,
#  'planned': 0,
#  'unk': 0,
#  'asked': 0,
#  'pre': 0,
#  'maldonado': 0,
#  'springs': 0,
#  'administrations': 0,
#  'organisational': 0,
#  'investors': 0,
#  'billing': 0,
#  'basis': 0,
#  'union': 0,
#  'fri': 0,
#  'three': 0,
#  'commission': 0,
#  'much': 0,
#  'reveffo': 0,
#  'interest': 0,
#  'basic': 0,
#  'entered': 0,
#  'celebration': 0,
#  'ann': 1,
#  'riley': 0,
#  'website': 0,
#  'digits': 0,
#  'life': 0,
#  'quantities': 0,
#  'irvine': 0,
#  'dave': 0,
#  'lift': 0,
#  'child': 0,
#  'worked': 0,
#  'exception': 0,
#  'administrative': 0,
#  'strangas': 0,
#  'neal': 0,
#  'bemidji': 0,
#  'near': 0,
#  'itinerary': 0,
#  'balance': 0,
#  'ix': 0,
#  'played': 0,
#  'clemsubject': 0,
#  'waukee': 0,
#  'it': 4,
#  'iv': 0,
#  'ii': 0,
#  'player': 0,
#  'im': 0,
#  'in': 6,
#  'ia': 1,
#  'campaigning': 0,
#  'ic': 1,
#  'mouse': 0,
#  'id': 1,
#  'sever': 0,
#  'if': 0,
#  'eastrans': 0,
#  'things': 0,
#  'make': 0,
#  'cumulative': 0,
#  'vlt': 0,
#  'any': 0,
#  'equistar': 0,
#  'split': 0,
#  'elliott': 0,
#  'couple': 0,
#  'fairly': 0,
#  'ephesians': 0,
#  'sacramento': 0,
#  'equitable': 0,
#  'delight': 0,
#  'josey': 0,
#  'kim': 0,
#  'opportunity': 0,
#  'thoughts': 0,
#  'buttes': 0,
#  'intrusion': 0,
#  'presto': 0,
#  'settled': 0,
#  'cdnow': 0,
#  'chantelle': 0,
#  'redeliveries': 0,
#  'claims': 0,
#  'corporate': 0,
#  'investments': 0,
#  'left': 0,
#  'protocol': 0,
#  'just': 0,
#  'waha': 0,
#  'distribute': 0,
#  'assigned': 0,
#  'unassigned': 0,
#  'identify': 0,
#  'yes': 0,
#  'yer': 0,
#  'somerville': 0,
#  'yet': 0,
#  'previous': 0,
#  'gretna': 0,
#  'hal': 0,
#  'had': 0,
#  'emphasis': 0,
#  'jefferson': 0,
#  'easy': 0,
#  'har': 0,
#  'has': 2,
#  'hat': 1,
#  'ops': 0,
#  'possible': 0,
#  'possibly': 0,
#  'birth': 0,
#  'opm': 0,
#  'eex': 0,
#  'desire': 0,
#  'county': 0,
#  'mcloughlin': 0,
#  'bobby': 0,
#  'performing': 0,
#  'manual': 0,
#  'avila': 0,
#  'wiatrek': 0,
#  'festivities': 0,
#  'attorney': 0,
#  'right': 0,
#  'dean': 0,
#  'creek': 0,
#  'deal': 1,
#  'people': 0,
#  'dead': 0,
#  'invoice': 0,
#  'wellhead': 0,
#  'dear': 0,
#  'txu': 0,
#  'tracked': 0,
#  'crofotn': 0,
#  'bottom': 0,
#  'notification': 0,
#  'fox': 0,
#  'continue': 0,
#  'donna': 0,
#  'iwl': 0,
#  'energy': 0,
#  'jester': 0,
#  'orem': 0,
#  'dollars': 0,
#  'o': 32,
#  'cohesively': 0,
#  'afternoon': 0,
#  'meoh': 0,
#  'commit': 0,
#  'kilgore': 0,
#  'corrine': 0,
#  'crutchfield': 0,
#  'automatically': 0,
#  'raised': 0,
#  'managers': 0,
#  'facility': 0,
#  'maxwell': 0,
#  'marshall': 0,
#  'son': 0,
#  'down': 0,
#  'lieu': 0,
#  'wrap': 0,
#  'america': 0,
#  'peoples': 0,
#  'comello': 0,
#  'support': 0,
#  'initial': 0,
#  'maffett': 0,
#  'joseph': 0,
#  'overhead': 0,
#  'jana': 0,
#  'happy': 0,
#  'offering': 0,
#  'offer': 0,
#  'clinics': 0,
#  'ford': 0,
#  'failure': 0,
#  'analyst': 0,
#  'administering': 0,
#  'attached': 0,
#  'until': 1,
#  'mccue': 0,
#  'tucson': 0,
#  'economic': 0,
#  'pest': 0,
#  'zajac': 0,
#  'dues': 0,
#  'delete': 0,
#  'proud': 0,
#  'toss': 0,
#  'tournament': 0,
#  'drive': 0,
#  'accounting': 5,
#  'floating': 0,
#  'magellan': 0,
#  'scherlyn': 0,
#  'vista': 0,
#  'lees': 0,
#  'floor': 0,
#  'excel': 0,
#  'flood': 0,
#  'acton': 0,
#  'pasadena': 0,
#  'republic': 0,
#  'holly': 0,
#  'roll': 0,
#  'intend': 0,
#  'garland': 0,
#  'outage': 0,
#  'utilities': 0,
#  'transported': 0,
#  'devon': 0,
#  'intent': 0,
#  'miranda': 0,
#  'authorities': 0,
#  'oncall': 0,
#  'weekend': 0,
#  'died': 0,
#  'billion': 0,
#  'happening': 0,
#  'assume': 0,
#  'daily': 0,
#  'teeth': 0,
#  'push': 0,
#  'cincinnati': 0,
#  'reviewers': 0,
#  'oss': 0,
#  'zeroed': 0,
#  'laura': 0,
#  'manager': 1,
#  'mile': 0,
#  'lauri': 0,
#  'seller': 0,
#  'carthagesubject': 0,
#  'hold': 0,
#  'william': 0,
#  'berner': 0,
#  'father': 0,
#  'editors': 0,
#  'answered': 0,
#  'finally': 0,
#  'repathing': 0,
#  'inerts': 0,
#  'suffered': 0,
#  'oversight': 0,
#  'downloading': 0,
#  'nomed': 0,
#  'congratulating': 0,
#  'wharton': 0,
#  'advised': 1,
#  'guylene': 0,
#  'word': 0,
#  'exact': 0,
#  'minute': 0,
#  'henrietta': 0,
#  'peg': 0,
#  'did': 0,
#  'leave': 0,
#  'item': 0,
#  'cooke': 0,
#  'team': 0,
#  'prevent': 0,
#  'talked': 0,
#  'dealing': 0,
#  'riesz': 0,
#  'sign': 0,
#  'krull': 0,
#  'trisha': 0,
#  'substanital': 0,
#  'goldston': 0,
#  'current': 0,
#  'beasley': 0,
#  'filled': 0,
#  'palmer': 0,
#  'jury': 0,
#  'henry': 0,
#  'bi': 0,
#  'deric': 0,
#  'hillier': 0,
#  'address': 0,
#  'alone': 0,
#  'along': 0,
#  'wait': 0,
#  'box': 0,
#  'revenues': 0,
#  'impacted': 0,
#  'bos': 0,
#  'suggestion': 0,
#  'bob': 0,
#  'myers': 0,
#  'boykin': 0,
#  'love': 0,
#  'confidentiality': 0,
#  'tacton': 0,
#  'daysubject': 0,
#  'marvelous': 0,
#  'flexibility': 0,
#  'crodrig': 0,
#  'balfour': 0,
#  'baer': 0,
#  'positive': 0,
#  'angry': 0,
#  'visit': 0,
#  'epsc': 0,
#  'perm': 0,
#  'wondering': 0,
#  'calgary': 0,
#  'thru': 0,
#  'bennett': 0,
#  'afford': 0,
#  'oregon': 0,
#  'downtown': 0,
#  'savior': 0,
#  'effort': 0,
#  'behalf': 0,
#  'markham': 0,
#  'mclarney': 0,
#  'unexciting': 0,
#  'originally': 0,
#  'soul': 0,
#  'believes': 0,
#  'enronavailso': 0,
#  'enronavailsl': 0,
#  'livonia': 0,
#  'values': 0,
#  'wasaff': 0,
#  'following': 0,
#  'making': 0,
#  'tune': 0,
#  'logon': 0,
#  'csikos': 0,
#  'claim': 0,
#  'kenneth': 0,
#  'awesome': 0,
#  'confused': 0,
#  'agent': 0,
#  'incremental': 0,
#  'fraley': 0,
#  'allowed': 0,
#  'longview': 0,
#  'clair': 0,
#  'cguggis': 0,
#  'winter': 0,
#  'charset': 0,
#  'pine': 0,
#  'msubject': 0,
#  'chemical': 0,
#  'till': 0,
#  'sunday': 0,
#  'djhyvl': 0,
#  'pure': 0,
#  'moorer': 0,
#  'mar': 0,
#  'may': 0,
#  'max': 0,
#  'misrepresented': 0,
#  'fed': 0,
#  'spot': 0,
#  'applications': 0,
#  'membership': 0,
#  'designed': 0,
#  'date': 0,
#  'gros': 0,
#  'revealed': 0,
#  'mao': 0,
#  'harmon': 0,
#  'stress': 0,
#  'natural': 0,
#  'outline': 0,
#  'sectors': 0,
#  'conscious': 0,
#  'ss': 0,
#  'maybe': 0,
#  'applicant': 0,
#  'thorne': 0,
#  'st': 1,
#  'so': 0,
#  'pullen': 0,
#  'definitions': 0,
#  'sa': 0,
#  'pulled': 0,
#  'sf': 0,
#  'talk': 0,
#  'sd': 0,
#  'pointed': 0,
#  'beaumont': 0,
#  'lsk': 0,
#  'entity': 0,
#  'course': 0,
#  'lst': 0,
#  'recoup': 0,
#  'lsp': 0,
#  'petrochemicals': 0,
#  'irena': 0,
#  'irene': 0,
#  'higginsville': 0,
#  'group': 0,
#  'monitor': 0,
#  'jim': 0,
#  'troubles': 0,
#  'enr': 0,
#  'rodessa': 0,
#  'tielp': 0,
#  'listing': 0,
#  'scribner': 0,
#  'mail': 0,
#  'main': 0,
#  'petition': 0,
#  'conoco': 0,
#  'tonia': 0,
#  'hscsubject': 0,
#  'finance': 0,
#  'views': 0,
#  'origination': 0,
#  'sooner': 0,
#  'nation': 0,
#  'elna': 0,
#  'lunch': 0,
#  'drilling': 0,
#  'workload': 0,
#  'didn': 0,
#  'revert': 0,
#  'quarter': 0,
#  'repaired': 0,
#  'square': 0,
#  'revised': 0,
#  'sponsor': 0,
#  'entering': 0,
#  'wilcrest': 0,
#  'morning': 0,
#  'description': 0,
#  'canada': 0,
#  'jackson': 0,
#  'rounding': 0,
#  'gonzales': 0,
#  'tuter': 0,
#  'contained': 0,
#  'pamela': 0,
#  'nicholie': 0,
#  'internet': 0,
#  'entitlements': 0,
#  'valdes': 0,
#  'correct': 0,
#  'after': 0,
#  'million': 0,
#  'orr': 0,
#  'weblink': 0,
#  'possibility': 0,
#  'quite': 0,
#  'romans': 0,
#  'shoemake': 0,
#  'mime': 0,
#  'senter': 0,
#  'mimi': 0,
#  'org': 0,
#  'remainder': 0,
#  'advance': 0,
#  'training': 0,
#  'language': 0,
#  'where': 0,
#  'owe': 0,
#  'thing': 0,
#  'think': 0,
#  'first': 0,
#  'spoken': 0,
#  'lone': 0,
#  'rachel': 0,
#  'potter': 0,
#  'one': 0,
#  'intrastate': 0,
#  'suspended': 0,
#  'calpine': 0,
#  'sounds': 0,
#  'open': 0,
#  'city': 0,
#  'little': 0,
#  'structured': 0,
#  'anyone': 0,
#  'guadalupe': 0,
#  'draft': 0,
#  'pmas': 0,
#  'structures': 0,
#  'williams': 0,
#  'eyes': 0,
#  'inefficient': 0,
#  'shawn': 0,
#  'memo': 0,
#  'broadcast': 0,
#  'hillary': 0,
#  'specialists': 0,
#  'representing': 0,
#  'sioux': 0,
#  'lucent': 0,
#  'cracks': 0,
#  'third': 0,
#  'sailing': 0,
#  'future': 0,
#  'rivas': 0,
#  'were': 0,
#  'txtsubject': 0,
#  'gathering': 0,
#  'san': 0,
#  'nicer': 0,
#  'topics': 0,
#  'turned': 0,
#  'locations': 0,
#  'say': 0,
#  'mesquite': 0,
#  'allen': 0,
#  'turner': 0,
#  'sap': 0,
#  'saw': 0,
#  'kevin': 0,
#  'sat': 0,
#  'efficient': 0,
#  'instructed': 0,
#  'note': 0,
#  'clearwater': 0,
#  'potential': 0,
#  'take': 0,
#  'performance': 0,
#  'channel': 0,
#  'pain': 0,
#  'norman': 0,
#  'normal': 0,
#  'track': 1,
#  'knew': 0,
#  'compress': 0,
#  'alarcon': 0,
#  'paid': 0,
#  'truelove': 0,
#  'assault': 0,
#  'filesubject': 0,
#  'sheets': 0,
#  'pair': 0,
#  'beth': 0,
#  'pager': 0,
#  'pages': 0,
#  'sutton': 0,
#  'especially': 0,
#  'huish': 0,
#  'average': 0,
#  'phil': 0,
#  'infections': 0,
#  'sale': 0,
#  'entex': 0,
#  'ways': 0,
#  'choate': 0,
#  'larry': 0,
#  'pathed': 0,
#  'refining': 0,
#  'affirmed': 0,
#  'shop': 0,
#  'playoffs': 0,
#  'show': 0,
#  'lotus': 0,
#  'winders': 0,
#  'merit': 0,
#  'elevate': 0,
#  'corner': 0,
#  'mops': 0,
#  'data': 0,
#  'slot': 0,
#  'slow': 0,
#  'otid': 0,
#  'transact': 0,
#  'dick': 0,
#  'behind': 0,
#  'foward': 0,
#  'going': 0,
#  'black': 0,
#  'treasury': 0,
#  'teary': 0,
#  'dispute': 0,
#  'ranking': 0,
#  'get': 0,
#  'contracts': 0,
#  'assistant': 0,
#  'designated': 0,
#  'prime': 0,
#  'resource': 0,
#  'dianne': 0,
#  'settings': 0,
#  'summary': 0,
#  'miles': 0,
#  'melanson': 0,
#  'liable': 0,
#  'tesoro': 0,
#  'communicated': 0,
#  'shoreview': 0,
#  'marlene': 0,
#  'interruptible': 0,
#  'sean': 0,
#  'eliminating': 0,
#  'calendar': 0,
#  'marvia': 0,
#  'registering': 0,
#  'avails': 0,
#  'representatives': 0,
#  'forecast': 0,
#  'enough': 0,
#  'affecting': 0,
#  'reading': 0,
#  'across': 0,
#  'august': 0,
#  'parent': 0,
#  'screen': 0,
#  'jr': 0,
#  'wednesday': 0,
#  'jo': 0,
#  'killing': 0,
#  'dates': 0,
#  'many': 0,
#  'trader': 0,
#  'trades': 0,
#  'according': 0,
#  'severson': 0,
#  's': 22,
#  'dated': 0,
#  'expression': 0,
#  'yearly': 0,
#  'anti': 0,
#  'cancel': 0,
#  'boas': 0,
#  'custody': 0,
#  'armstrong': 0,
#  'stretch': 0,
#  'barry': 0,
#  'deuteronomy': 0,
#  'vacation': 0,
#  'mark': 0,
#  'almighty': 0,
#  'combined': 0,
#  'mary': 0,
#  'fig': 0,
#  'wants': 0,
#  'shopping': 0,
#  'benoit': 0,
#  ...}
